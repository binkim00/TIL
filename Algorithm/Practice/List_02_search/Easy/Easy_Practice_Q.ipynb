# %%
####################################################
# [문제 1] 2차원 배열 순회
# N x N 크기의 2차원 배열이 주어진다.
#
# 배열의 모든 원소를 순회하며
# 값의 총합을 출력하시오.
#
# [입력 예시]
# 1
# 3
# 1 2 3
# 4 5 6
# 7 8 9
#
# [출력 예시]
# #1 45
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = [list(map(int, input().split())) for _ in range(N)]

    total = 0

    # TODO: 이중 반복문으로 모든 원소 순회하며 합 구하기

    print(f"#{tc} {total}")

# %%
####################################################
# [문제 2] 델타를 이용한 상하좌우 합
# N x N 크기의 2차원 배열이 주어진다.
#
# 각 칸에 대해 상, 하, 좌, 우에 존재하는
# 값들의 합을 구하고,
# 그 중 최댓값을 출력하시오.
#
# 배열 범위를 벗어나는 경우는 제외한다.
#
# [입력 예시]
# 1
# 3
# 1 2 3
# 4 5 6
# 7 8 9
#
# [출력 예시]
# #1 20
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = [list(map(int, input().split())) for _ in range(N)]

    max_sum = 0

    # 델타 배열 (상, 하, 좌, 우)
    di = [-1, 1, 0, 0]
    dj = [0, 0, -1, 1]

    # TODO:
    # 모든 좌표 (i, j)에 대해
    # 상하좌우를 검사하여 합을 구하고
    # 최댓값 갱신하기

    print(f"#{tc} {max_sum}")

# %%
####################################################
# [문제 3] 부분 수열 합
# 길이가 N인 수열이 주어진다.
#
# 연속된 부분 수열 중
# 합이 가장 큰 값을 출력하시오.
#
# (반드시 하나 이상의 원소를 포함해야 한다)
#
# [입력 예시]
# 1
# 5
# 1 -3 5 -2 9
#
# [출력 예시]
# #1 12
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().split()))

    max_sum = -1000000000

    # TODO:
    # 시작 인덱스 i
    # 끝 인덱스 j를 이용해
    # 모든 연속 부분 수열의 합을 계산

    print(f"#{tc} {max_sum}")

# %%
####################################################
# [문제 4] 버블 정렬과 선택 정렬 구현
# 길이가 N인 정수 배열이 주어진다.
#
# 1) 버블 정렬로 오름차순 정렬
# 2) 선택 정렬로 오름차순 정렬
#
# 두 정렬 결과를 각각 출력하시오.
#
# 내장 정렬 함수 사용 금지
#
# [입력 예시]
# 1
# 5
# 64 25 10 22 11
#
# [출력 예시]
# #1
# bubble: 10 11 22 25 64
# select: 10 11 22 25 64
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().split()))

    bubble = arr[:]   # 버블 정렬용
    select = arr[:]   # 선택 정렬용

    # TODO 1: 버블 정렬 구현

    # TODO 2: 선택 정렬 구현

    print(f"#{tc}")
    print("bubble:", *bubble)
    print("select:", *select)
