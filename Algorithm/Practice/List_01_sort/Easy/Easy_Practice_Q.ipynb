# %%
####################################################
# [문제] 탐욕 알고리즘 (Greedy)
# 배열이 주어진다.
# 현재 배열에서
# 가장 큰 값을 찾아 출력하시오.
#
# [유형] 탐욕 (현재 최선 선택)
#
# [입력 예시]
# 1
# 5
# 3 7 2 9 1
#
# [출력 예시]
# #1 9
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().split()))

    max_value = arr[0]

    # TODO: 가장 큰 값 찾기

    print(f"#{tc} {max_value}")

# %%
####################################################
# [문제] 탐욕 + 시뮬레이션
# 배열에서
# 가장 큰 값에서 1을 빼고
# 가장 작은 값에 1을 더한다.
# 이 작업을 1번 수행한 뒤
# 최고점과 최저점의 차이를 출력하시오.
#
# [유형] 탐욕 + 시뮬레이션
#
# [입력 예시]
# 1
# 5
# 7 4 2 9 1
#
# [출력 예시]
# #1 6
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().split()))

    # TODO: max_idx, min_idx 찾기
    # TODO: 값 이동
    # TODO: 최종 차이 계산
    result = 0

    print(f"#{tc} {result}")

# %%
####################################################
# [문제] 탐욕 + 반복 시뮬레이션
# 배열에서
# 가장 큰 값에서 1을 빼고
# 가장 작은 값에 1을 더하는 작업을
# K번 수행한다.
# K번 수행 후,
# 최고점과 최저점의 차이를 출력하시오.
#
# [유형] 탐욕 + 시뮬레이션
#
# [입력 예시]
# 1
# 5 2
# 7 4 2 9 1
#
# [출력 예시]
# #1 5
####################################################

T = int(input())
for tc in range(1, T + 1):
    N, K = map(int, input().split())
    arr = list(map(int, input().split()))

    # TODO: K번 반복
    # TODO: 매번 max_idx / min_idx 찾기
    # TODO: 값 이동
    result = 0

    print(f"#{tc} {result}")

# %%
####################################################
# [문제] 카운트 배열 (Counting) 개수 세기
# 0부터 9까지의 숫자로 이루어진 배열이 주어진다.
# 각 숫자가 몇 번씩 등장했는지 출력하시오.
#
# [유형] 카운트 배열
#
# [입력 예시]
# 1
# 7
# 1222333
#
# [출력 예시]
# #1 [0, 1, 2, 3, 0, 0, 0, 0, 0, 0]
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().strip()))

    cnt = [0] * 10

    # TODO: 개수 세기

    print(f"#{tc} {cnt}")

# %%
####################################################
# [문제] 카운트 배열 (Counting) 최빈값
# 0부터 9까지의 숫자로 이루어진 배열이 주어진다.
# 가장 많이 등장한 숫자와
# 그 등장 횟수를 출력하시오.
# (개수가 같다면 숫자가 큰 쪽)
#
# [유형] 카운트 배열
#
# [입력 예시]
# 1
# 7
# 1222333
#
# [출력 예시]
# #1 3 3
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().strip()))

    cnt = [0] * 10
    max_num = 0
    max_cnt = 0

    # TODO: 개수 세기
    # TODO: 최빈값 찾기

    print(f"#{tc} {max_num} {max_cnt}")

# %%
####################################################
# [문제] 부분 순열 / 부분 수열
# 서로 다른 정수들이 주어진다.
# 서로 다른 두 개를 골라
# 두 수의 차이의 절댓값 중
# 가장 큰 값을 출력하시오.
#
# [유형] 부분 순열 (이중 for 완전 검색)
#
# [입력 예시]
# 1
# 4
# 1 3 5 9
#
# [출력 예시]
# #1 8
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().split()))

    max_diff = 0

    # TODO: i != j 인 경우 완전 검색

    print(f"#{tc} {max_diff}")

# %%
####################################################
# [문제] 부분 수열 (투 포인터)
# 문자열 A와 문자열 B가 주어진다.
# B가 A의 부분 수열이면 1,
# 아니면 0을 출력하시오.
#
# [유형] 부분 수열
#
# [입력 예시]
# 1
# abcdef
# ace
#
# [출력 예시]
# #1 1
####################################################

T = int(input())
for tc in range(1, T + 1):
    A = input().strip()
    B = input().strip()

    result = 0

    # TODO: A를 앞에서부터 보며 B 인덱스 이동

    print(f"#{tc} {result}")
