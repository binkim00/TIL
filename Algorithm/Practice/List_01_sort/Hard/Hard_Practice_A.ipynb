# %%
####################################################
# [문제] 탐욕 + 시뮬레이션 (다중 조건)
# 길이가 N인 배열이 주어진다.
# 배열에서 가장 큰 값에서 1을 빼고
# 가장 작은 값에 1을 더하는 작업을
# 최대 K번 수행할 수 있다.
#
# 단, 다음 조건을 만족하지 않으면
# 해당 작업은 수행하지 않는다.
#
# 1) 가장 큰 값과 가장 작은 값의 차이가 2 이상일 때만 수행
# 2) 가장 큰 값이 여러 개라면 가장 왼쪽 것을 선택
# 3) 가장 작은 값이 여러 개라면 가장 오른쪽 것을 선택
#
# 작업 종료 후
# 최고점과 최저점의 차이를 출력하시오.
#
# [유형] 탐욕 + 시뮬레이션 (Hard)
#
# [입력 예시]
# 1
# 6 5
# 4 4 9 1 1 6
#
# [출력 예시]
# #1 1
####################################################

T = int(input())
for tc in range(1, T + 1):
    N, K = map(int, input().split())
    arr = list(map(int, input().split()))

    # TODO: K번 반복
    # TODO: max/min + 위치 조건 처리
    # TODO: 중단 조건 처리
    result = 0

    print(f"#{tc} {result}")

# %%
####################################################
# [문제] 카운트 배열 + 누적 판단
# 0부터 100까지의 점수가 주어진다.
# 점수 분포를 분석하려 한다.
#
# 다음 조건을 만족하는 점수를 출력하시오.
#
# 1) 등장 횟수가 가장 많은 점수
# 2) 단, 해당 점수 이상을 받은 학생 수가
#    전체의 절반 이상이어야 한다.
# 3) 조건을 만족하는 점수가 여러 개면
#    점수가 가장 높은 것을 출력
#
# 조건을 만족하는 점수가 없으면 -1 출력
#
# [유형] 카운트 배열 (Hard)
#
# [입력 예시]
# 1
# 8
# 55 60 60 70 70 70 80 90
#
# [출력 예시]
# #1 70
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    scores = list(map(int, input().split()))

    cnt = [0] * 101

    # TODO: 개수 세기
    # TODO: 누적 개수 계산
    # TODO: 조건 만족 점수 찾기
    result = -1

    print(f"#{tc} {result}")

# %%
####################################################
# [문제] 부분 순열 (3중 완전검색)
# 서로 다른 N개의 정수가 주어진다.
# 서로 다른 세 개를 골라
# 다음 값을 계산한다.
#
# |a - b| + |b - c|
#
# 이 값이 K 이하인 경우 중
# 가장 큰 값을 출력하시오.
#
# [유형] 부분 순열 (Hard)
#
# [입력 예시]
# 1
# 5 6
# 1 2 4 7 8
#
# [출력 예시]
# #1 6
####################################################

T = int(input())
for tc in range(1, T + 1):
    N, K = map(int, input().split())
    arr = list(map(int, input().split()))

    max_value = 0

    # TODO: i != j != k
    # TODO: 조건 만족 시 최댓값 갱신

    print(f"#{tc} {max_value}")

# %%
####################################################
# [문제] 부분 수열 + 다중 시작점
# 문자열 A와 문자열 B가 주어진다.
# 문자열 A 안에서
# 문자열 B가 부분 수열로
# 등장하는 모든 시작 위치의 개수를 출력하시오.
#
# [유형] 부분 수열 (Hard)
#
# [입력 예시]
# 1
# ababcabc
# abc
#
# [출력 예시]
# #1 3
####################################################

T = int(input())
for tc in range(1, T + 1):
    A = input().strip()
    B = input().strip()

    count = 0

    # TODO: 시작 인덱스 이동
    # TODO: 부분 수열 판별

    print(f"#{tc} {count}")
