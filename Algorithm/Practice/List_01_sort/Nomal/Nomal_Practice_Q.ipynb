# %%
####################################################
# [문제] 탐욕 + 조건 중단
# 배열에서
# 가장 큰 값에서 1을 빼고
# 가장 작은 값에 1을 더하는 작업을
# K번 수행한다.
#
# 단, 최고점과 최저점의 차이가
# 1 이하가 되면 작업을 중단한다.
#
# 작업 종료 후
# 최고점과 최저점의 차이를 출력하시오.
#
# [유형] 탐욕 + 시뮬레이션
#
# [입력 예시]
# 1
# 5 10
# 7 4 2 9 1
#
# [출력 예시]
# #1 1
####################################################

T = int(input())
for tc in range(1, T + 1):
    N, K = map(int, input().split())
    arr = list(map(int, input().split()))

    # TODO: K번 반복
    # TODO: 매번 max / min 찾기
    # TODO: 차이가 1 이하이면 중단
    result = 0

    print(f"#{tc} {result}")

# %%
####################################################
# [문제] 카운트 배열 조건 포함 최빈값
# 0부터 9까지의 숫자로 이루어진 배열이 주어진다.
# 짝수 숫자 중에서
# 가장 많이 등장한 숫자와
# 그 등장 횟수를 출력하시오.
#
# (조건을 만족하는 숫자가 없으면 0 0 출력)
#
# [유형] 카운트 배열
#
# [입력 예시]
# 1
# 7
# 1222333
#
# [출력 예시]
# #1 2 2
####################################################

T = int(input())
for tc in range(1, T + 1):
    N = int(input())
    arr = list(map(int, input().strip()))

    cnt = [0] * 10
    max_num = 0
    max_cnt = 0

    # TODO: 개수 세기
    # TODO: 짝수만 비교
    # TODO: 조건 만족 없을 때 처리

    print(f"#{tc} {max_num} {max_cnt}")

# %%
####################################################
# [문제] 부분 순열 + 조건
# 서로 다른 정수들이 주어진다.
# 서로 다른 두 개를 골라
# 두 수의 합이
# K 이하인 경우 중
# 가장 큰 합을 출력하시오.
#
# [유형] 부분 순열 (이중 for 완전 검색)
#
# [입력 예시]
# 1
# 5 10
# 1 3 5 7 9
#
# [출력 예시]
# #1 10
####################################################

T = int(input())
for tc in range(1, T + 1):
    N, K = map(int, input().split())
    arr = list(map(int, input().split()))

    max_sum = 0

    # TODO: i != j
    # TODO: 합이 K 이하인지 확인
    # TODO: 최댓값 갱신

    print(f"#{tc} {max_sum}")

# %%
####################################################
# [문제] 부분 수열 개수 세기
# 문자열 A와 문자열 B가 주어진다.
# A 안에서 B가 부분 수열로
# 몇 번 등장하는지 출력하시오.
#
# [유형] 부분 수열
#
# [입력 예시]
# 1
# ababc
# abc
#
# [출력 예시]
# #1 2
####################################################

T = int(input())
for tc in range(1, T + 1):
    A = input().strip()
    B = input().strip()

    count = 0

    # TODO: 부분 수열 검사
    # TODO: 시작 위치 바꿔가며 개수 세기

    print(f"#{tc} {count}")
