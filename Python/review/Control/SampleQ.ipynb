# %% [markdown]
# ## 1. 숫자가 3의 배수인지 판별하는 함수
#
# - 3의 배수면 `"3의 배수"`
# - 아니면 `"아님"`

# %%
def check_multiple_of_three(num):
    if num % 3 == 0:
        return "3의 배수"
    else:
        return "아님"


print(check_multiple_of_three(9))   # 3의 배수
print(check_multiple_of_three(10))  # 아님
print(check_multiple_of_three(0))   # 3의 배수
# Out:
# 3의 배수
# 아님
# 3의 배수

# %% [markdown]
# ## 2. 숫자가 10 이상인지 아닌지 판별하기

# %%
def is_ten_or_more(num):
    if num >= 10:
        return "10 이상"
    else:
        return "10 미만"

print(is_ten_or_more(10))  # 10 이상
print(is_ten_or_more(7))   # 10 미만
# Out:
# 10 이상
# 10 미만

# %% [markdown]
# ## 3. 리스트에서 가장 큰 수 찾기 ㅁㅁㅁ
#
# - `max()` 사용 금지

# %%
def find_max(lst):
    max_num = lst[0]
    for num in lst:
        if num > max_num:
            max_num = num
    return max_num

print(find_max([3, 1, 9, 4]))   # 9
print(find_max([10, 5, 7]))     # 10
# Out:
# 9
# 10

# %% [markdown]
# ## 4. 딕셔너리에서 특정 key의 value 반환하기 ㅁㅁㅁ
#
# - key가 없으면 `"없음"` 반환

# %%
def get_value(dic, key):
    if key in dic:
        return dic[key]
    else:
        return "없음"

user = {"name": "kim", "age": 20}

print(get_value(user, "name"))   # kim
print(get_value(user, "job"))    # 없음
# Out:
# kim
# 없음

# %% [markdown]
# ## 5. 리스트 평균 구하기 ㅁㅁㅁ
#
# - `sum`, `len` 사용 금지

# %%
def average(lst):
    addnum = 0
    count = 0
    for num in lst:
        addnum += num
        count += 1
    return addnum / count


print(average([10, 20, 30]))   # 20.0
print(average([1, 2]))         # 1.5
# Out:
# 20.0
# 1.5

# %% [markdown]
# ## 6. 문자열 길이 구하기 ㅁㅁ
#
# - `len()` 사용 금지

# %%
def string_length(text):
    count = 0
    for str in text:
        count += 1
    return count


print(string_length("hello"))   # 5
print(string_length(""))        # 0
# Out:
# 5
# 0

# %% [markdown]
# ## 7. 리스트에 있는 모든 숫자 출력하기 ㅁㅁ

# %%
def print_numbers(lst):
    for num in lst:
        print(num)


print_numbers([1, 3, 5])
# 1
# 3
# 5
# Out:
# 1
# 3
# 5

# %% [markdown]
# ## 8. 리스트에서 짝수만 출력하기 ㅁㅁ

# %%
def print_even(lst):
    for num in lst:
        if num % 2 == 0:
            print(num)

print_even([1, 2, 3, 4, 10])
# 2
# 4
# 10
# Out:
# 2
# 4
# 10

# %% [markdown]
# ## 9. 문자열에서 공백 개수 세기

# %%
def count_spaces(text):
    count = 0
    for em in text:
        if em == " ":
            count += 1
    return count


print(count_spaces("hello world"))  # 1
print(count_spaces("a b c d"))       # 3
# Out:
# 1
# 3

# %% [markdown]
# ## 10. 리스트 요소 등장 횟수 세기 ㅁㅁㅁㅁㅁ
#
# - 딕셔너리로 결과 반환

# %%
def count_items(lst):
    diclist = {}
    for num in lst:
        if num in diclist:
            diclist[num] += 1
        else:
            diclist[num] = 1   
    return diclist



print(count_items([1, 1, 2, 3, 3, 3]))
# {1: 2, 2: 1, 3: 3}
# Out:
# {1: 2, 2: 1, 3: 3}
