# %%
############## 주의 ##############
# input 함수는 사용하지 않습니다.
#
# [문제]
# numbers 리스트에서 "연속으로 증가하는 구간"의
# 최대 길이를 반환하는 함수를 작성하시오.
#
# [예시 설명]
# [1, 2, 3, 1, 2] → 증가 구간: [1,2,3] 길이 3
#
# [요구조건]
# - 숫자가 이전 값보다 클 때만 증가로 판단
# - 증가가 끊기면 길이를 초기화
def longest_increasing(numbers):
    pass
    # 여기에 코드를 작성하여 함수를 완성합니다.


############## 테스트 코드 삭제 금지 #################
print(longest_increasing([1, 2, 3, 1, 2]))      # 3
print(longest_increasing([5, 4, 3, 2, 1]))      # 1
print(longest_increasing([1, 2, 3, 4, 5]))      # 5
#####################################################

# %%
############## 주의 ##############
# input 함수는 사용하지 않습니다.
#
# [문제]
# numbers 리스트에서
# "짝수이면서 10보다 큰 최초의 값"을 반환하시오.
# 없으면 -1을 반환하시오.
#
# [요구조건]
# - 조건을 만족하면 즉시 종료
# - 끝까지 없으면 -1 반환
def first_even_over_ten(numbers):
    pass
    # 여기에 코드를 작성하여 함수를 완성합니다.


############## 테스트 코드 삭제 금지 #################
print(first_even_over_ten([1, 3, 8, 9, 12, 14]))  # 12
print(first_even_over_ten([2, 4, 6, 8]))         # -1
#####################################################

# %%
############## 주의 ##############
# input 함수는 사용하지 않습니다.
#
# [문제]
# scores 딕셔너리에서
# 점수가 기준점수 이상인 사람의 이름만
# 리스트로 반환하시오.
#
# [요구조건]
# - 반환 순서는 딕셔너리 순서를 따른다
def passed_students(scores, 기준점수):
    pass
    # 여기에 코드를 작성하여 함수를 완성합니다.


############## 테스트 코드 삭제 금지 #################
scores = {"kim": 85, "lee": 55, "park": 70}
print(passed_students(scores, 60))  # ['kim', 'park']
#####################################################

# %%
############## 주의 ##############
# input 함수는 사용하지 않습니다.
#
# [문제]
# text 문자열에서 가장 많이 등장한 문자를 반환하시오.
# (공백도 문자로 취급)
#
# [요구조건]
# - 등장 횟수를 먼저 센다
# - 가장 큰 값을 가진 문자를 찾는다
# - 동점이면 먼저 등장한 문자를 유지한다
def most_common_char(text):
    pass
    # 여기에 코드를 작성하여 함수를 완성합니다.


############## 테스트 코드 삭제 금지 #################
print(most_common_char("jazz is good"))  # 'z'
print(most_common_char("aabbcc"))        # 'a'
#####################################################

# %%
############## 주의 ##############
# input 함수는 사용하지 않습니다.
#
# [문제]
# orders 리스트에는 주문 상태가 순서대로 기록되어 있다.
# "PAID" 다음에 바로 "CANCEL"이 나온 횟수를 구하시오.
#
# [예시]
# ["PAID", "CANCEL", "PAID", "DONE"] → 1
#
# [요구조건]
# - 현재 상태와 다음 상태를 함께 비교한다
def count_paid_cancel(orders):
    pass
    # 여기에 코드를 작성하여 함수를 완성합니다.


############## 테스트 코드 삭제 금지 #################
print(count_paid_cancel(["PAID", "CANCEL", "PAID", "DONE"]))      # 1
print(count_paid_cancel(["PAID", "PAID", "CANCEL", "CANCEL"]))   # 0
#####################################################
