# %%
############## 주의 ##############
# 복잡한 JSON 구조에서 데이터 수집/가공/출력 (여러 단계 한 파일)
# - input 함수는 사용하지 않습니다.
# - 아래 테스트 코드(출력) 삭제 금지
# - 단계별로 함수를 완성합니다.
# - (주의) print 힌트/중간 출력은 테스트 코드 외에는 추가하지 않는 것을 권장합니다.

data = {
    "status": 200,
    "message": "OK",
    "meta": {
        "now_page": 1,
        "max_page": 2,
        "total_count": 6
    },
    "result": {
        "companyList": [
            {
                "companyId": "C01",
                "companyName": "A-Corp",
                "region": {"city": "Seoul", "country": "KR"},
                "departments": [
                    {
                        "deptId": "D11",
                        "deptName": "Backend",
                        "members": [
                            {
                                "userId": 101,
                                "profile": {"name": "Kim", "mail": "kim@test.com"},
                                "tags": ["python", "api", "backend"],
                                "scores": {"coding": [80, 90], "cs": [70]},
                                "websites": ["https://kim.dev", "http://kim.blog"]
                            },
                            {
                                "userId": 102,
                                "profile": {"name": "Park", "mail": "park@test.com"},
                                "tags": [],
                                "scores": {"coding": [100], "cs": []},
                                "websites": []
                            },
                        ]
                    },
                    {
                        "deptId": "D12",
                        "deptName": "Data",
                        "members": [
                            {
                                "userId": 103,
                                "profile": {"name": "Choi", "mail": "choi@test.com"},
                                "tags": ["data", "python"],
                                "scores": {"coding": [88, 92, 95], "cs": [85]},
                                "websites": ["https://choi.ai"]
                            },
                        ]
                    },
                ]
            },
            {
                "companyId": "C02",
                "companyName": "B-Lab",
                "region": {"city": "Busan", "country": "KR"},
                "departments": [
                    {
                        "deptId": "D21",
                        "deptName": "Frontend",
                        "members": [
                            {
                                "userId": 201,
                                "profile": {"name": "Lee", "mail": "lee@test.com"},
                                "tags": ["frontend"],
                                "scores": {"coding": [60, 75], "cs": [50, 55]},
                                "websites": ["http://lee.dev"]
                            },
                        ]
                    }
                ]
            },
            {
                "companyId": "C03",
                "companyName": "C-Works",
                "region": {"city": "Incheon", "country": "KR"},
                "departments": [
                    {
                        "deptId": "D31",
                        "deptName": "Ops",
                        "members": [
                            {
                                "userId": 301,
                                "profile": {"name": "Han", "mail": "han@test.com"},
                                "tags": ["infra", "linux"],
                                "scores": {"coding": [77], "cs": [60]},
                                "websites": ["https://han.ops", "https://han.site"]
                            },
                            {
                                "userId": 302,
                                "profile": {"name": "Yoon", "mail": "yoontest.com"},
                                "tags": ["linux"],
                                "scores": {"coding": [], "cs": [65, 70]},
                                "websites": ["http://yoon.me"]
                            },
                        ]
                    }
                ]
            }
        ]
    }
}


############## 주의 ##############
# [Step 1] 전체 멤버 수 구하기
# - companyList 안의 모든 departments 안의 모든 members 수를 세어 정수로 반환합니다.
def total_member_count(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 2] 모든 멤버 이름만 리스트로 반환하기
# - 순서는 data에 등장하는 순서를 그대로 유지합니다.
def all_member_names(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 3] 태그가 없는 멤버 이름만 반환하기
# - tags 리스트 길이가 0인 멤버의 profile["name"]을 리스트로 반환합니다.
def no_tag_members(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 4] 이메일 형식 간단 검증하기
# - profile["mail"]에 '@'가 없으면 "invalid", 있으면 "valid"로 판단합니다.
# - 결과는 {이름: 'valid' or 'invalid'} 형태의 딕셔너리로 반환합니다.
def email_validation_map(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 5] 회사별 멤버 이름 모으기 (딕셔너리 누적)
# - 결과 예시: {'A-Corp': ['Kim', 'Park', 'Choi'], 'B-Lab': ['Lee'], 'C-Works': ['Han', 'Yoon']}
def group_members_by_company(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 6] 멤버별 평균 점수 계산하기
# - coding 점수 리스트 + cs 점수 리스트를 합쳐 전체 평균을 구합니다.
# - 점수가 아예 없으면 평균은 0.0 으로 합니다.
# - 결과는 {이름: 평균(float)} 딕셔너리로 반환합니다.
def member_total_avg_score(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 7] "python" 태그가 있는 멤버 요약 리스트 만들기
# - tags에 "python"이 포함된 멤버만 대상으로 합니다.
# - 각 멤버를 아래 형태의 딕셔너리로 가공해 리스트에 담아 반환합니다.
#   {"name": 이름, "company": 회사명, "dept": 부서명, "tag_count": 태그개수}
def python_member_summaries(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 8] 회사별 평균 점수(회사 단위) 구하기
# - 회사 소속 멤버들의 (Step 6에서 구한 멤버별 평균점수)을 다시 평균내어 회사 평균을 구합니다.
# - 결과는 {회사명: 회사평균(float)} 딕셔너리로 반환합니다.
def company_avg_score(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 주의 ##############
# [Step 9] 출력용 라인 만들기 (가공 + 문자열 리스트)
# - 각 멤버에 대해 아래 형식 문자열을 만들어 리스트로 반환합니다.
#   "{회사명}/{부서명} - {이름} - mail:{valid|invalid} - avg:{평균점수}"
# - mail valid/invalid는 Step 4 기준 사용
# - 평균점수는 Step 6 기준 사용 (소수점 1자리까지 반올림)
def build_report_lines(data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


#####################################################
############## 테스트 코드 삭제 금지 #################
print(total_member_count(data))  # 6

print(all_member_names(data))
# ['Kim', 'Park', 'Choi', 'Lee', 'Han', 'Yoon']

print(no_tag_members(data))  # ['Park']

print(email_validation_map(data))
# {'Kim': 'valid', 'Park': 'valid', 'Choi': 'valid', 'Lee': 'valid', 'Han': 'valid', 'Yoon': 'invalid'}

print(group_members_by_company(data))
# {'A-Corp': ['Kim', 'Park', 'Choi'], 'B-Lab': ['Lee'], 'C-Works': ['Han', 'Yoon']}

print(member_total_avg_score(data))
# {'Kim': 80.0, 'Park': 100.0, 'Choi': 90.0, 'Lee': 60.0, 'Han': 68.5, 'Yoon': 67.5}

print(python_member_summaries(data))
# [
#   {'name': 'Kim', 'company': 'A-Corp', 'dept': 'Backend', 'tag_count': 3},
#   {'name': 'Choi', 'company': 'A-Corp', 'dept': 'Data', 'tag_count': 2}
# ]

print(company_avg_score(data))
# {'A-Corp': 90.0, 'B-Lab': 60.0, 'C-Works': 68.0}

lines = build_report_lines(data)
print(lines)
# [
#   'A-Corp/Backend - Kim - mail:valid - avg:80.0',
#   'A-Corp/Backend - Park - mail:valid - avg:100.0',
#   'A-Corp/Data - Choi - mail:valid - avg:90.0',
#   'B-Lab/Frontend - Lee - mail:valid - avg:60.0',
#   'C-Works/Ops - Han - mail:valid - avg:68.5',
#   'C-Works/Ops - Yoon - mail:invalid - avg:67.5'
# ]
#####################################################
