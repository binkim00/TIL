# %%
############## 주의 ##############
# and/or 시 출력
# 두 값 a, b가 주어질 때
# - a가 참(0, "", [], {}가 아니면)이고 b가 참이면 "둘 다 참"
# - 둘 중 하나만 참이면 "하나만 참"
# - 둘 다 거짓이면 "둘 다 거짓"
# input 함수는 사용하지 않습니다.
def and_or_message(a, b):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(and_or_message(1, 2))         # "둘 다 참"
print(and_or_message(0, 2))         # "하나만 참"
print(and_or_message("", []))       # "둘 다 거짓"
#####################################################

# %%
############## 주의 ##############
# 중첩 for문 + 딕셔너리 가공
# students에서 "모든 과목 점수 중" 80점 이상인 점수만 모아 리스트로 반환
# (학생 순서대로, 과목 순서대로 담기)
# input 함수는 사용하지 않습니다.
def collect_over_80(students):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
students = [
    {"name": "김수원", "scores": {"국어": 90, "영어": 80, "수학": 70}},
    {"name": "진서영", "scores": {"국어": 70, "영어": 80, "수학": 90}},
    {"name": "이예승", "scores": {"국어": 80, "영어": 80, "수학": 80}},
]
print(collect_over_80(students))  # [90, 80, 80, 90, 80, 80, 80]
#####################################################

# %%
############## 주의 ##############
# 중첩 for문 + 누적
# 과목별 최고 점수(국어/영어/수학)를 딕셔너리로 반환
# input 함수는 사용하지 않습니다.
def subject_max(students):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
students = [
    {"name": "김수원", "scores": {"국어": 90, "영어": 80, "수학": 70}},
    {"name": "진서영", "scores": {"국어": 70, "영어": 85, "수학": 90}},
    {"name": "이예승", "scores": {"국어": 88, "영어": 78, "수학": 82}},
]
print(subject_max(students))  # {'국어': 90, '영어': 85, '수학': 90}
#####################################################

# %%
############## 주의 ##############
# while문 활용
# numbers에서 앞에서부터 검사하면서 "연속된 양수"만 result에 담고,
# 음수가 처음 등장하면 즉시 중단하고 result 반환
# input 함수는 사용하지 않습니다.
def take_until_negative(numbers):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(take_until_negative([3, 2, 1, -1, 5, 6]))  # [3, 2, 1]
print(take_until_negative([-1, 2, 3]))           # []
#####################################################

# %%
############## 주의 ##############
# while문 + 카운트( len() 사용 금지 )
# words에서 길이가 4 이상인 단어 개수를 반환
# input 함수는 사용하지 않습니다.
def count_long_words(words):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(count_long_words(["hi", "hello", "world", "a", "python"]))  # 3
#####################################################

# %%
############## 주의 ##############
# 재귀함수 활용
# numbers 리스트의 합을 "재귀"로 구해서 반환
# (반복문 사용하지 않기)
# input 함수는 사용하지 않습니다.
def sum_recursive(numbers):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(sum_recursive([1, 2, 3, 4]))  # 10
print(sum_recursive([]))           # 0
#####################################################

# %%
############## 주의 ##############
# 리스트 컴프리헨션 활용
# words에서 "알파벳으로만 이루어진 단어"만 소문자로 바꿔 리스트로 반환
# (반복문 for 문으로 append 금지, 컴프리헨션으로만)
# input 함수는 사용하지 않습니다.
def lower_alpha_only(words):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(lower_alpha_only(["HELLO", "hi!", "WORLD", "123", "PyThOn"]))
# ['hello', 'world', 'python']
#####################################################

# %%
############## 주의 ##############
# lambda + map 활용
# numbers의 각 원소에 대해
# - 짝수면 0
# - 홀수면 원래 값의 2배
# 를 적용한 새 리스트를 반환 (map + lambda로만)
# input 함수는 사용하지 않습니다.
def odd_double_even_zero(numbers):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(odd_double_even_zero([1, 2, 3, 4, 5]))  # [2, 0, 6, 0, 10]
#####################################################

# %%
############## 주의 ##############
# API(json) 활용 "형태 연습" (requests 사용 X)
# 아래 sample_data는 API에서 받아온 json이라고 가정합니다.
# 모든 상품의 "fin_prdt_nm"만 뽑아서 리스트로 반환하세요.
# input 함수는 사용하지 않습니다.
def extract_product_names(sample_data):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
sample_data = {
    "result": {
        "baseList": [
            {"fin_prdt_cd": "001", "fin_prdt_nm": "튼튼예금"},
            {"fin_prdt_cd": "002", "fin_prdt_nm": "행복적금"},
            {"fin_prdt_cd": "003", "fin_prdt_nm": "스마트예금"},
        ]
    }
}
print(extract_product_names(sample_data))  # ['튼튼예금', '행복적금', '스마트예금']
#####################################################

# %%
############## 주의 ##############
# 메서드 활용(특히 자료형 메서드)
# text에서 공백을 기준으로 단어를 나눈 뒤,
# - 양 끝의 특수문자(!?. ,)를 제거하고
# - 빈 문자열은 제외하고
# - 모두 소문자로 바꾼 리스트를 반환
# input 함수는 사용하지 않습니다.
def clean_words(text):
    # 여기에 코드를 작성하여 함수를 완성합니다.
    pass


############## 테스트 코드 삭제 금지 #################
print(clean_words("Hello,  WORLD!!  Python... is Good?"))
# ['hello', 'world', 'python', 'is', 'good']
#####################################################

# %%
############## 주의 ##############
# 모듈 생성 및 활용 "형태 연습"
# 아래 요구사항대로 코드를 작성한다고 가정합니다.
#
# 1) my_utils.py 파일에
#    - add(a, b): a+b 반환
#    - avg(numbers): numbers 평균 반환 (len 금지, 직접 세기)
# 2) main.py 파일에서 my_utils를 import 해서
#    - add(3, 4) 결과 출력
#    - avg([10, 20, 30, 40]) 결과 출력
#
# 여기서는 "두 파일" 내용을 각각 함수 형태로 적어보세요.
# (실제로 파일 나눠 작성하는 연습용)
#
# input 함수는 사용하지 않습니다.
def write_module_practice():
    pass


############## 테스트 코드 삭제 금지 #################
# 이 문제는 출력 예시만 제공합니다.
print("add(3,4) => 7")
print("avg([10,20,30,40]) => 25.0")
#####################################################
